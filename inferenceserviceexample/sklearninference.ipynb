# %%
pip install kserve==0.7.0
# Out:
# Collecting kserve==0.7.0
#   Downloading kserve-0.7.0-py3-none-any.whl (284 kB)
#      |████████████████████████████████| 284 kB 1.6 MB/s eta 0:00:01
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: adal>=1.2.2 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.2.7)
# Collecting azure-identity>=1.6.0
#   Downloading azure_identity-1.9.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 17.6 MB/s eta 0:00:01
# Collecting grpcio==1.38.1
#   Downloading grpcio-1.38.1-cp38-cp38-manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 22.5 MB/s eta 0:00:01
# Collecting cffi==1.14.6
#   Downloading cffi-1.14.6-cp38-cp38-manylinux1_x86_64.whl (411 kB)
#      |████████████████████████████████| 411 kB 49.0 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (2.8.1)
# Collecting google-cloud-storage==1.41.1
#   Downloading google_cloud_storage-1.41.1-py2.py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 129.0 MB/s eta 0:00:01
# Collecting psutil>=5.0
#   Downloading psutil-5.9.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#      |████████████████████████████████| 283 kB 86.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.22.3)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.26.5)
# Requirement already satisfied: cryptography==3.4.7 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (3.4.7)
# Requirement already satisfied: kubernetes>=12.0.0 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (12.0.1)
# Collecting google-api-core==1.29.0
#   Downloading google_api_core-1.29.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.5 MB/s s eta 0:00:01
# Collecting azure-storage-blob==12.8.1
#   Downloading azure_storage_blob-12.8.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 53.0 MB/s eta 0:00:01
# Collecting azure-core==1.17.0
#   Downloading azure_core-1.17.0-py2.py3-none-any.whl (165 kB)
#      |████████████████████████████████| 165 kB 69.0 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (49.6.0.post20210108)
# Requirement already satisfied: avro>=1.10.1 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.11.0)
# Requirement already satisfied: deprecation==2.1.0 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (2.1.0)
# Collecting googleapis-common-protos==1.53.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 92.9 MB/s eta 0:00:01
# Requirement already satisfied: minio<7.0.0,>=4.0.9 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (6.0.2)
# Requirement already satisfied: six>=1.15 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.16.0)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (2021.5.30)
# Collecting google-auth==1.34.0
#   Downloading google_auth-1.34.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 118.4 MB/s eta 0:00:01
# Requirement already satisfied: table-logger>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (0.3.6)
# Collecting argparse>=1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting botocore==1.21.18
#   Downloading botocore-1.21.18-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 26.2 MB/s eta 0:00:01
# Collecting jmespath==0.10.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting idna==3.2
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 12.8 MB/s  eta 0:00:01
# Requirement already satisfied: cloudevents>=1.2.0 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (1.2.0)
# Collecting azure-identity==1.6.0
#   Downloading azure_identity-1.6.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 80.5 MB/s eta 0:00:01
# Collecting ray[serve]==1.5.0
#   Downloading ray-1.5.0-cp38-cp38-manylinux2014_x86_64.whl (51.3 MB)
#      |████████████████████████████████| 51.3 MB 45.8 MB/s eta 0:00:01    |█▌                              | 2.4 MB 26.7 MB/s eta 0:00:02     |██████████████▎                 | 22.9 MB 26.7 MB/s eta 0:00:02
# Requirement already satisfied: tornado>=6.0.0 in /opt/conda/lib/python3.8/site-packages (from kserve==0.7.0) (6.1)
# Collecting boto3==1.18.18
#   Downloading boto3-1.18.18-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.18.4 in /opt/conda/lib/python3.8/site-packages (from azure-core==1.17.0->kserve==0.7.0) (2.25.1)
# Collecting msal-extensions~=0.3.0
#   Downloading msal_extensions-0.3.1-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.7.0
#   Downloading msal-1.17.0-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 14.8 MB/s  eta 0:00:01
# Collecting msrest>=0.6.18
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 7.1 MB/s  eta 0:00:01
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.3 MB/s  eta 0:00:01
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi==1.14.6->kserve==0.7.0) (2.20)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.8/site-packages (from deprecation==2.1.0->kserve==0.7.0) (20.9)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core==1.29.0->kserve==0.7.0) (3.17.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.8/site-packages (from google-api-core==1.29.0->kserve==0.7.0) (2021.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth==1.34.0->kserve==0.7.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth==1.34.0->kserve==0.7.0) (4.8)
# Requirement already satisfied: google-cloud-core<3.0dev,>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from google-cloud-storage==1.41.1->kserve==0.7.0) (2.2.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from google-cloud-storage==1.41.1->kserve==0.7.0) (2.3.2)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.8/site-packages (from ray[serve]==1.5.0->kserve==0.7.0) (3.2.0)
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 90.3 MB/s eta 0:00:01
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from ray[serve]==1.5.0->kserve==0.7.0) (5.4.1)
# Collecting filelock
#   Downloading filelock-3.6.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/conda/lib/python3.8/site-packages (from ray[serve]==1.5.0->kserve==0.7.0) (0.11.0)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.8/site-packages (from ray[serve]==1.5.0->kserve==0.7.0) (7.1.2)
# Collecting pydantic>=1.8
#   Downloading pydantic-1.9.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.6 MB)
#      |████████████████████████████████| 12.6 MB 72.2 MB/s eta 0:00:01    |█████████████████████▉          | 8.6 MB 72.2 MB/s eta 0:00:01
# Collecting aioredis
#   Downloading aioredis-2.0.1-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 13.6 MB/s eta 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 44.8 MB/s eta 0:00:01
# Requirement already satisfied: colorama in /opt/conda/lib/python3.8/site-packages (from ray[serve]==1.5.0->kserve==0.7.0) (0.4.4)
# Collecting redis>=3.5.0
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 60.1 MB/s eta 0:00:01
# Collecting opencensus
#   Downloading opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 60.2 MB/s eta 0:00:01
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.11-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 52.5 MB/s eta 0:00:01
# Collecting gpustat
#   Downloading gpustat-0.6.0.tar.gz (78 kB)
#      |████████████████████████████████| 78 kB 10.8 MB/s eta 0:00:011
# Collecting uvicorn
#   Downloading uvicorn-0.17.6-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.0 MB/s  eta 0:00:01
# Collecting fastapi
#   Downloading fastapi-0.75.2-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 5.9 MB/s s eta 0:00:01
# Collecting starlette
#   Downloading starlette-0.19.0-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 15.6 MB/s eta 0:00:01
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from adal>=1.2.2->kserve==0.7.0) (2.3.0)
# Collecting google-cloud-core<3.0dev,>=1.6.0
#   Downloading google_cloud_core-2.3.0-py2.py3-none-any.whl (29 kB)
#   Downloading google_cloud_core-2.2.2-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.8/site-packages (from google-resumable-media<3.0dev,>=1.3.0->google-cloud-storage==1.41.1->kserve==0.7.0) (1.3.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/lib/python3.8/site-packages (from kubernetes>=12.0.0->kserve==0.7.0) (1.0.1)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.8/site-packages (from kubernetes>=12.0.0->kserve==0.7.0) (1.3.1)
# Requirement already satisfied: configparser in /opt/conda/lib/python3.8/site-packages (from minio<7.0.0,>=4.0.9->kserve==0.7.0) (5.2.0)
# Collecting portalocker<3,>=1.0
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 368 kB/s  eta 0:00:01
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging->deprecation==2.1.0->kserve==0.7.0) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth==1.34.0->kserve==0.7.0) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic>=1.8->ray[serve]==1.5.0->kserve==0.7.0) (4.1.1)
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: deprecated>=1.2.3 in /opt/conda/lib/python3.8/site-packages (from redis>=3.5.0->ray[serve]==1.5.0->kserve==0.7.0) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.8/site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[serve]==1.5.0->kserve==0.7.0) (1.13.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.18.4->azure-core==1.17.0->kserve==0.7.0) (4.0.0)
# Collecting requests>=2.18.4
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.5 MB/s  eta 0:00:01
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->kubernetes>=12.0.0->kserve==0.7.0) (3.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 10.3 MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      |████████████████████████████████| 158 kB 92.4 MB/s eta 0:00:01
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (308 kB)
#      |████████████████████████████████| 308 kB 55.8 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray[serve]==1.5.0->kserve==0.7.0) (21.2.0)
# Collecting starlette
#   Downloading starlette-0.17.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: anyio<4,>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from starlette->ray[serve]==1.5.0->kserve==0.7.0) (3.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.8/site-packages (from anyio<4,>=3.0.0->starlette->ray[serve]==1.5.0->kserve==0.7.0) (1.2.0)
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->ray[serve]==1.5.0->kserve==0.7.0) (0.17.3)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting h11>=0.8
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 11.0 MB/s eta 0:00:01
# Collecting asgiref>=3.4.0
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: gpustat, nvidia-ml-py3
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=884a7b2c1710ca77e3d9e79340ab1f8215247f60870bf34c58016b62a578f7a9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0d/d9/80/b6cbcdc9946c7b50ce35441cc9e7d8c5a9d066469ba99bae44
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19191 sha256=dc708c329888753fae0b3a5e30f1fc2be0c2386063fe16a5b5629275f7b351e3
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b9/b1/68/cb4feab29709d4155310d29a421389665dcab9eb3b679b527b
# Successfully built gpustat nvidia-ml-py3
# Installing collected packages: multidict, idna, frozenlist, charset-normalizer, cffi, cachetools, yarl, requests, googleapis-common-protos, google-auth, async-timeout, aiosignal, psutil, opencensus-context, nvidia-ml-py3, jmespath, google-api-core, blessings, aiohttp, starlette, redis, pydantic, py-spy, portalocker, opencensus, msgpack, msal, isodate, h11, grpcio, gpustat, filelock, botocore, asgiref, aioredis, aiohttp-cors, uvicorn, s3transfer, ray, msrest, msal-extensions, google-cloud-core, fastapi, azure-core, google-cloud-storage, boto3, azure-storage-blob, azure-identity, argparse, kserve
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.14.5
#     Uninstalling cffi-1.14.5:
#       Successfully uninstalled cffi-1.14.5
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.4
#     Uninstalling cachetools-4.2.4:
#       Successfully uninstalled cachetools-4.2.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.55.0
#     Uninstalling googleapis-common-protos-1.55.0:
#       Successfully uninstalled googleapis-common-protos-1.55.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.7.1
#     Uninstalling google-api-core-2.7.1:
#       Successfully uninstalled google-api-core-2.7.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.2.3
#     Uninstalling google-cloud-core-2.2.3:
#       Successfully uninstalled google-cloud-core-2.2.3
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.44.0
#     Uninstalling google-cloud-storage-1.44.0:
#       Successfully uninstalled google-cloud-storage-1.44.0
#   Attempting uninstall: azure-storage-blob
#     Found existing installation: azure-storage-blob 2.1.0
#     Uninstalling azure-storage-blob-2.1.0:
#       Successfully uninstalled azure-storage-blob-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kfserving 0.5.1 requires azure-storage-blob<=2.1.0,>=1.3.0, but you have azure-storage-blob 12.8.1 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-2.0.1 aiosignal-1.2.0 argparse-1.4.0 asgiref-3.5.0 async-timeout-4.0.2 azure-core-1.17.0 azure-identity-1.6.0 azure-storage-blob-12.8.1 blessings-1.7 boto3-1.18.18 botocore-1.21.18 cachetools-4.2.2 cffi-1.14.6 charset-normalizer-2.0.12 fastapi-0.75.2 filelock-3.6.0 frozenlist-1.3.0 google-api-core-1.29.0 google-auth-1.34.0 google-cloud-core-2.2.2 google-cloud-storage-1.41.1 googleapis-common-protos-1.53.0 gpustat-0.6.0 grpcio-1.38.1 h11-0.13.0 idna-3.2 isodate-0.6.1 jmespath-0.10.0 kserve-0.7.0 msal-1.17.0 msal-extensions-0.3.1 msgpack-1.0.3 msrest-0.6.21 multidict-6.0.2 nvidia-ml-py3-7.352.0 opencensus-0.8.0 opencensus-context-0.1.2 portalocker-2.4.0 psutil-5.9.0 py-spy-0.3.11 pydantic-1.9.0 ray-1.5.0 redis-4.2.2 requests-2.27.1 s3transfer-0.5.2 starlette-0.17.1 uvicorn-0.17.6 yarl-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from kubernetes import client 
from kserve import KServeClient
from kserve import constants
from kserve import utils
from kserve import V1beta1InferenceService
from kserve import V1beta1InferenceServiceSpec
from kserve import V1beta1PredictorSpec
from kserve import V1beta1SKLearnSpec

# %%
pip install ray
# Out:
# Requirement already satisfied: ray in /opt/conda/lib/python3.8/site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.8/site-packages (from ray) (1.22.3)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.8/site-packages (from ray) (3.8.1)
# Requirement already satisfied: gpustat in /opt/conda/lib/python3.8/site-packages (from ray) (0.6.0)
# Requirement already satisfied: pydantic>=1.8 in /opt/conda/lib/python3.8/site-packages (from ray) (1.9.0)
# Requirement already satisfied: protobuf>=3.15.3 in /opt/conda/lib/python3.8/site-packages (from ray) (3.17.3)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.8/site-packages (from ray) (7.1.2)
# Requirement already satisfied: grpcio>=1.28.1 in /opt/conda/lib/python3.8/site-packages (from ray) (1.38.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from ray) (1.0.3)
# Requirement already satisfied: aioredis in /opt/conda/lib/python3.8/site-packages (from ray) (2.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.8/site-packages (from ray) (3.6.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.8/site-packages (from ray) (3.2.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/conda/lib/python3.8/site-packages (from ray) (0.11.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from ray) (2.27.1)
# Requirement already satisfied: opencensus in /opt/conda/lib/python3.8/site-packages (from ray) (0.8.0)
# Requirement already satisfied: aiohttp-cors in /opt/conda/lib/python3.8/site-packages (from ray) (0.7.0)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.8/site-packages (from ray) (0.4.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.8/site-packages (from ray) (5.4.1)
# Requirement already satisfied: redis>=3.5.0 in /opt/conda/lib/python3.8/site-packages (from ray) (4.2.2)
# Requirement already satisfied: py-spy>=0.2.0 in /opt/conda/lib/python3.8/site-packages (from ray) (0.3.11)
# Requirement already satisfied: six>=1.5.2 in /opt/conda/lib/python3.8/site-packages (from grpcio>=1.28.1->ray) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic>=1.8->ray) (4.1.1)
# Requirement already satisfied: packaging>=20.4 in /opt/conda/lib/python3.8/site-packages (from redis>=3.5.0->ray) (20.9)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/conda/lib/python3.8/site-packages (from redis>=3.5.0->ray) (4.0.2)
# Requirement already satisfied: deprecated>=1.2.3 in /opt/conda/lib/python3.8/site-packages (from redis>=3.5.0->ray) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.8/site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray) (1.13.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.4->redis>=3.5.0->ray) (2.4.7)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp->ray) (1.7.2)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp->ray) (3.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /opt/conda/lib/python3.8/site-packages (from gpustat->ray) (7.352.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.8/site-packages (from gpustat->ray) (5.9.0)
# Requirement already satisfied: blessings>=1.6 in /opt/conda/lib/python3.8/site-packages (from gpustat->ray) (1.7)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from jsonschema->ray) (49.6.0.post20210108)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->ray) (0.17.3)
# Requirement already satisfied: opencensus-context==0.1.2 in /opt/conda/lib/python3.8/site-packages (from opencensus->ray) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from opencensus->ray) (1.29.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray) (1.34.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /opt/conda/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray) (1.53.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray) (2021.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray) (4.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->ray) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->ray) (1.26.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
namespace = utils.get_default_target_namespace()

# %%
KServe = KServeClient()

# %%
name="sklearn-iris"
KServe.get(name, namespace=namespace, watch=True, timeout_seconds=120)
# Out:
# NAME                 READY                           PREV                    LATEST URL
# sklearn-iris         True                               0                       100 http://sklearn-iris.kubeflow-user-example-com.example.com

# %%
import requests

isvc_resp = KServe.get(name, namespace=namespace)
isvc_url = isvc_resp['status']['address']['url']
print(isvc_url)
# Out:
# http://sklearn-iris.kubeflow-user-example-com.svc.cluster.local/v1/models/sklearn-iris:predict

# %%
inference_input= {
 "instances": [
   [6.8,  2.8,  4.8,  1.4],
  [6.0,  3.4,  4.5,  1.6]
  ]
}
response = requests.post(isvc_url, json=inference_input)
print(response.text)
# Out:
# {"predictions": [1, 1]}
